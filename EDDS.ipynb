# %% [markdown]
# <a href="https://colab.research.google.com/github/cfuss/edds/blob/main/EDDS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import polars as pl
import seaborn as sns
import matplotlib.pyplot as plt

headerListGenre = ['genre', 'id']
headerListInfo=[]
headerListUser=['user id','age','gender','occupation','zip code']
headerListItem=['movie id','movie title','release date','video release date','IMDb URL','unknown','Action','Adventure','Animation','Childrens','Comedy','Crime','Documentary','Drama','Fantasy','Film-Noir','Horror','Musical','Mystery','Romance','Sci-Fi','Thriller','War','Western']
headerListOccupation=['occupation']

userData = pl.read_csv('/content/edds_data/u.user', separator='|',has_header=False, new_columns=headerListUser)
userData.head()
#userData.describe()
# Out:
# shape: (5, 5)
# ┌─────────┬─────┬────────┬────────────┬──────────┐
# │ user id ┆ age ┆ gender ┆ occupation ┆ zip code │
# │ ---     ┆ --- ┆ ---    ┆ ---        ┆ ---      │
# │ i64     ┆ i64 ┆ str    ┆ str        ┆ str      │
# ╞═════════╪═════╪════════╪════════════╪══════════╡
# │ 1       ┆ 24  ┆ M      ┆ technician ┆ 85711    │
# │ 2       ┆ 53  ┆ F      ┆ other      ┆ 94043    │
# │ 3       ┆ 23  ┆ M      ┆ writer     ┆ 32067    │
# │ 4       ┆ 24  ┆ M      ┆ technician ┆ 43537    │
# │ 5       ┆ 33  ┆ F      ┆ other      ┆ 15213    │
# └─────────┴─────┴────────┴────────────┴──────────┘

# %%
(
sns.kdeplot(data=userData, x='age')
.set(title='Test')
)

plt.show()
